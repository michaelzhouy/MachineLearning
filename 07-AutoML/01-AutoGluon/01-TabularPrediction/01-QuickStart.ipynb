# %%
from autogluon.tabular import TabularDataset, TabularPredictor

# %% [markdown]
# # 分类

# %% [markdown]
# ## 读取数据

# %%
train_data = TabularDataset('https://autogluon.s3.amazonaws.com/datasets/Inc/train.csv')
subsample_size = 500  # subsample subset of data for faster demo, try setting this to much larger values
train_data = train_data.sample(n=subsample_size, random_state=0)
train_data.head()
# Out:
#        age workclass  fnlwgt      education  education-num  \
# 6118    51   Private   39264   Some-college             10
# 23204   58   Private   51662           10th              6
# 29590   40   Private  326310   Some-college             10
# 18116   37   Private  222450        HS-grad              9
# 33964   62   Private  109190      Bachelors             13
#
#             marital-status        occupation    relationship    race      sex  \
# 6118    Married-civ-spouse   Exec-managerial            Wife   White   Female
# 23204   Married-civ-spouse     Other-service            Wife   White   Female
# 29590   Married-civ-spouse      Craft-repair         Husband   White     Male
# 18116        Never-married             Sales   Not-in-family   White     Male
# 33964   Married-civ-spouse   Exec-managerial         Husband   White     Male
#
#        capital-gain  capital-loss  hours-per-week  native-country   class
# 6118              0             0              40   United-States    >50K
# 23204             0             0               8   United-States   <=50K
# 29590             0             0              44   United-States   <=50K
# 18116             0          2339              40     El-Salvador   <=50K
# 33964         15024             0              40   United-States    >50K

# %%
train_data.info()
# Out:
# <class 'autogluon.core.dataset.TabularDataset'>
# Int64Index: 500 entries, 6118 to 24772
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             500 non-null    int64
#  1   workclass       500 non-null    object
#  2   fnlwgt          500 non-null    int64
#  3   education       500 non-null    object
#  4   education-num   500 non-null    int64
#  5   marital-status  500 non-null    object
#  6   occupation      500 non-null    object
#  7   relationship    500 non-null    object
#  8   race            500 non-null    object
#  9   sex             500 non-null    object
#  10  capital-gain    500 non-null    int64
#  11  capital-loss    500 non-null    int64
#  12  hours-per-week  500 non-null    int64
#  13  native-country  500 non-null    object
#  14  class           500 non-null    object
# dtypes: int64(6), object(9)
# memory usage: 62.5+ KB

# %%
label = 'class'
print("Summary of class variable: \n", train_data[label].describe())
# Out:
# Summary of class variable:
#  count        500
# unique         2
# top        <=50K
# freq         365
# Name: class, dtype: object

# %% [markdown]
# ## fit()

# %%
save_path = 'agModels-predictClass'  # specifies folder to store trained models
predictor = TabularPredictor(label=label, path=save_path).fit(train_data)
# Out:
# Beginning AutoGluon training ...
# AutoGluon will save models to "agModels-predictClass/"
# AutoGluon Version:  0.2.0
# Train Data Rows:    500
# Train Data Columns: 14
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [' >50K', ' <=50K']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 =  >50K, class 0 =  <=50K
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive ( >50K) vs negative ( <=50K) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    217296.08 MB
# 	Train Data (Original)  Memory Usage: 0.29 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', [])    : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('object', []) : 8 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 8 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 		('int', [])      : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 	0.1s = Fit runtime
# 	14 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.03 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.11s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 400, Val Rows: 100
# Fitting model: KNeighborsUnif ...
# 	0.73	 = Validation accuracy score
# 	0.0s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.65	 = Validation accuracy score
# 	0.0s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMXT ...
# /root/anaconda3/lib/python3.6/site-packages/fsspec/__init__.py:47: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for spec in entry_points.get("fsspec.specs", []):
# 	0.83	 = Validation accuracy score
# 	1.31s	 = Training runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.85	 = Validation accuracy score
# 	2.71s	 = Training runtime
# 	0.03s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	0.84	 = Validation accuracy score
# 	0.8s	 = Training runtime
# 	0.12s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.83	 = Validation accuracy score
# 	0.68s	 = Training runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.84	 = Validation accuracy score
# 	1.05s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.82	 = Validation accuracy score
# 	0.71s	 = Training runtime
# 	0.12s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.82	 = Validation accuracy score
# 	0.68s	 = Training runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# No improvement since epoch 8: early stopping
# 	0.84	 = Validation accuracy score
# 	5.11s	 = Training runtime
# 	0.04s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.85	 = Validation accuracy score
# 	0.44s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetMXNet ...
# 	0.84	 = Validation accuracy score
# 	12.02s	 = Training runtime
# 	0.22s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	0.83	 = Validation accuracy score
# 	0.6s	 = Training runtime
# 	0.04s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.85	 = Validation accuracy score
# 	0.67s	 = Training runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 29.5s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("agModels-predictClass/")

# %% [markdown]
# ## 读取test data

# %%
test_data = TabularDataset('https://autogluon.s3.amazonaws.com/datasets/Inc/test.csv')
y_test = test_data[label]  # values to predict
test_data_nolab = test_data.drop(columns=[label])  # delete label column to prove we're not cheating
test_data_nolab.head()
# Out:
# Loaded data from: https://autogluon.s3.amazonaws.com/datasets/Inc/test.csv | Columns = 15 / 15 | Rows = 9769 -> 9769
#    age          workclass  fnlwgt      education  education-num  \
# 0   31            Private  169085           11th              7
# 1   17   Self-emp-not-inc  226203           12th              8
# 2   47            Private   54260      Assoc-voc             11
# 3   21            Private  176262   Some-college             10
# 4   17            Private  241185           12th              8
#
#         marital-status        occupation relationship    race      sex  \
# 0   Married-civ-spouse             Sales         Wife   White   Female
# 1        Never-married             Sales    Own-child   White     Male
# 2   Married-civ-spouse   Exec-managerial      Husband   White     Male
# 3        Never-married   Exec-managerial    Own-child   White   Female
# 4        Never-married    Prof-specialty    Own-child   White     Male
#
#    capital-gain  capital-loss  hours-per-week  native-country
# 0             0             0              20   United-States
# 1             0             0              45   United-States
# 2             0          1887              60   United-States
# 3             0             0              30   United-States
# 4             0             0              20   United-States

# %% [markdown]
# ## 评估结果

# %%
predictor = TabularPredictor.load(save_path)  # unnecessary, just demonstrates how to load previously-trained predictor from file

y_pred = predictor.predict(test_data_nolab)
print("Predictions:  \n", y_pred)
# 评估结果
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: accuracy on test data: 0.8397993653393387
# Evaluations on test data:
# {
#     "accuracy": 0.8397993653393387,
#     "balanced_accuracy": 0.7437076677780596,
#     "mcc": 0.5295565206264157,
#     "f1": 0.6242496998799519,
#     "precision": 0.7038440714672441,
#     "recall": 0.5608283002588438
# }
# Predictions:
#  0        <=50K
# 1        <=50K
# 2         >50K
# 3        <=50K
# 4        <=50K
#          ...
# 9764     <=50K
# 9765     <=50K
# 9766     <=50K
# 9767     <=50K
# 9768     <=50K
# Name: class, Length: 9769, dtype: object

# %% [markdown]
# ## 查看每个model情况

# %%
predictor.leaderboard(test_data, silent=True)
# Out:
#                   model  score_test  score_val  pred_time_test  pred_time_val  \
# 0               XGBoost    0.842666       0.85        0.124808       0.015478
# 1      RandomForestGini    0.841335       0.84        0.231724       0.119614
# 2      RandomForestEntr    0.840721       0.83        0.242968       0.115446
# 3              LightGBM    0.839799       0.85        0.032772       0.028593
# 4   WeightedEnsemble_L2    0.839799       0.85        0.035677       0.029467
# 5            LightGBMXT    0.839390       0.83        0.022310       0.029306
# 6              CatBoost    0.837957       0.84        0.030301       0.014467
# 7        ExtraTreesEntr    0.834783       0.82        0.232491       0.116090
# 8        ExtraTreesGini    0.834476       0.82        0.230504       0.116096
# 9         LightGBMLarge    0.827823       0.83        0.026900       0.036274
# 10      NeuralNetFastAI    0.827413       0.84        0.732688       0.039107
# 11       NeuralNetMXNet    0.818815       0.84        1.826992       0.221197
# 12       KNeighborsUnif    0.725970       0.73        0.109615       0.111288
# 13       KNeighborsDist    0.695158       0.65        0.111212       0.108269
#
#      fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0    0.438999                 0.124808                0.015478
# 1    0.803098                 0.231724                0.119614
# 2    0.678261                 0.242968                0.115446
# 3    2.708905                 0.032772                0.028593
# 4    3.381279                 0.002905                0.000874
# 5    1.312838                 0.022310                0.029306
# 6    1.045222                 0.030301                0.014467
# 7    0.676039                 0.232491                0.116090
# 8    0.707770                 0.230504                0.116096
# 9    0.600974                 0.026900                0.036274
# 10   5.108123                 0.732688                0.039107
# 11  12.016742                 1.826992                0.221197
# 12   0.004181                 0.109615                0.111288
# 13   0.002718                 0.111212                0.108269
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0            0.438999            1       True         11
# 1            0.803098            1       True          5
# 2            0.678261            1       True          6
# 3            2.708905            1       True          4
# 4            0.672374            2       True         14
# 5            1.312838            1       True          3
# 6            1.045222            1       True          7
# 7            0.676039            1       True          9
# 8            0.707770            1       True          8
# 9            0.600974            1       True         13
# 10           5.108123            1       True         10
# 11          12.016742            1       True         12
# 12           0.004181            1       True          1
# 13           0.002718            1       True          2

# %% [markdown]
# ## predict_proba()

# %%
# 预测概率
pred_probs = predictor.predict_proba(test_data_nolab)
pred_probs.head(5)
# Out:
#       <=50K      >50K
# 0  0.949797  0.050203
# 1  0.945973  0.054027
# 2  0.433299  0.566701
# 3  0.991393  0.008607
# 4  0.949908  0.050092

# %% [markdown]
# ## fit_summary() 查看fit情况

# %%
results = predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                   model  score_val  pred_time_val   fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0               XGBoost       0.85       0.015478   0.438999                0.015478           0.438999            1       True         11
# 1              LightGBM       0.85       0.028593   2.708905                0.028593           2.708905            1       True          4
# 2   WeightedEnsemble_L2       0.85       0.029467   3.381279                0.000874           0.672374            2       True         14
# 3              CatBoost       0.84       0.014467   1.045222                0.014467           1.045222            1       True          7
# 4       NeuralNetFastAI       0.84       0.039107   5.108123                0.039107           5.108123            1       True         10
# 5      RandomForestGini       0.84       0.119614   0.803098                0.119614           0.803098            1       True          5
# 6        NeuralNetMXNet       0.84       0.221197  12.016742                0.221197          12.016742            1       True         12
# 7            LightGBMXT       0.83       0.029306   1.312838                0.029306           1.312838            1       True          3
# 8         LightGBMLarge       0.83       0.036274   0.600974                0.036274           0.600974            1       True         13
# 9      RandomForestEntr       0.83       0.115446   0.678261                0.115446           0.678261            1       True          6
# 10       ExtraTreesEntr       0.82       0.116090   0.676039                0.116090           0.676039            1       True          9
# 11       ExtraTreesGini       0.82       0.116096   0.707770                0.116096           0.707770            1       True          8
# 12       KNeighborsUnif       0.73       0.111288   0.004181                0.111288           0.004181            1       True          1
# 13       KNeighborsDist       0.65       0.108269   0.002718                0.108269           0.002718            1       True          2
# Number of models trained: 14
# Types of models trained:
# {'XTModel', 'KNNModel', 'LGBModel', 'WeightedEnsembleModel', 'NNFastAiTabularModel', 'TabularNeuralNetModel', 'XGBoostModel', 'RFModel', 'CatBoostModel'}
# Bagging used: False
# Multi-layer stack-ensembling used: False
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', []) : 8 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# ('int', [])      : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# Plot summary of models saved to file: agModels-predictClass/SummaryOfModels.html
# *** End of fit() summary ***

# %%
print("AutoGluon infers problem type is: ", predictor.problem_type) # 推断问题类型
print("AutoGluon identified the following types of features:")
print(predictor.feature_metadata)
# Out:
# AutoGluon infers problem type is:  binary
# AutoGluon identified the following types of features:
# ('category', []) : 8 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# ('int', [])      : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]

# %%
predictor.leaderboard(test_data, silent=True)
# Out:
#                   model  score_test  score_val  pred_time_test  pred_time_val  \
# 0               XGBoost    0.842666       0.85        0.112451       0.015478
# 1      RandomForestGini    0.841335       0.84        0.229361       0.119614
# 2      RandomForestEntr    0.840721       0.83        0.233600       0.115446
# 3              LightGBM    0.839799       0.85        0.053413       0.028593
# 4   WeightedEnsemble_L2    0.839799       0.85        0.056061       0.029467
# 5            LightGBMXT    0.839390       0.83        0.033110       0.029306
# 6              CatBoost    0.837957       0.84        0.028480       0.014467
# 7        ExtraTreesEntr    0.834783       0.82        0.231794       0.116090
# 8        ExtraTreesGini    0.834476       0.82        0.230221       0.116096
# 9         LightGBMLarge    0.827823       0.83        0.054976       0.036274
# 10      NeuralNetFastAI    0.827413       0.84        0.492435       0.039107
# 11       NeuralNetMXNet    0.818815       0.84        2.109936       0.221197
# 12       KNeighborsUnif    0.725970       0.73        0.109620       0.111288
# 13       KNeighborsDist    0.695158       0.65        0.111017       0.108269
#
#      fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0    0.438999                 0.112451                0.015478
# 1    0.803098                 0.229361                0.119614
# 2    0.678261                 0.233600                0.115446
# 3    2.708905                 0.053413                0.028593
# 4    3.381279                 0.002648                0.000874
# 5    1.312838                 0.033110                0.029306
# 6    1.045222                 0.028480                0.014467
# 7    0.676039                 0.231794                0.116090
# 8    0.707770                 0.230221                0.116096
# 9    0.600974                 0.054976                0.036274
# 10   5.108123                 0.492435                0.039107
# 11  12.016742                 2.109936                0.221197
# 12   0.004181                 0.109620                0.111288
# 13   0.002718                 0.111017                0.108269
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0            0.438999            1       True         11
# 1            0.803098            1       True          5
# 2            0.678261            1       True          6
# 3            2.708905            1       True          4
# 4            0.672374            2       True         14
# 5            1.312838            1       True          3
# 6            1.045222            1       True          7
# 7            0.676039            1       True          9
# 8            0.707770            1       True          8
# 9            0.600974            1       True         13
# 10           5.108123            1       True         10
# 11          12.016742            1       True         12
# 12           0.004181            1       True          1
# 13           0.002718            1       True          2

# %%
predictor.predict(test_data, model='LightGBM')
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3        <=50K
# 4        <=50K
#          ...
# 9764     <=50K
# 9765     <=50K
# 9766     <=50K
# 9767     <=50K
# 9768     <=50K
# Name: class, Length: 9769, dtype: object

# %%
time_limit = 60  # for quick demonstration only, you should set this to longest time you are willing to wait (in seconds)
metric = 'roc_auc'  # specify your evaluation metric here
predictor = TabularPredictor(label, eval_metric=metric, path='agModels-predictClass_auc').fit(train_data, time_limit=time_limit, presets='best_quality')
predictor.leaderboard(test_data, silent=True)
# Out:
# Presets specified: ['best_quality']
# Beginning AutoGluon training ... Time limit = 60s
# AutoGluon will save models to "agModels-predictClass_auc/"
# AutoGluon Version:  0.2.0
# Train Data Rows:    500
# Train Data Columns: 14
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [' >50K', ' <=50K']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 =  >50K, class 0 =  <=50K
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive ( >50K) vs negative ( <=50K) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    214977.9 MB
# 	Train Data (Original)  Memory Usage: 0.29 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', [])    : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('object', []) : 8 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 8 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 		('int', [])      : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 	0.1s = Fit runtime
# 	14 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.03 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.17s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric argument of fit()
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 59.83s of the 59.82s of remaining time.
# 	0.5196	 = Validation roc_auc score
# 	0.0s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 59.71s of the 59.7s of remaining time.
# 	0.537	 = Validation roc_auc score
# 	0.0s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 59.59s of the 59.59s of remaining time.
# 	0.8814	 = Validation roc_auc score
# 	3.53s	 = Training runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 55.81s of the 55.81s of remaining time.
# 	0.867	 = Validation roc_auc score
# 	5.64s	 = Training runtime
# 	0.26s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 49.87s of the 49.86s of remaining time.
# 	0.8847	 = Validation roc_auc score
# 	0.79s	 = Training runtime
# 	0.14s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 48.91s of the 48.91s of remaining time.
# 	0.8863	 = Validation roc_auc score
# 	0.69s	 = Training runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 48.07s of the 48.06s of remaining time.
# 	0.8875	 = Validation roc_auc score
# 	8.37s	 = Training runtime
# 	0.08s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 39.59s of the 39.59s of remaining time.
# 	0.8929	 = Validation roc_auc score
# 	0.69s	 = Training runtime
# 	0.14s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 38.74s of the 38.74s of remaining time.
# 	0.8939	 = Validation roc_auc score
# 	0.68s	 = Training runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 37.89s of the 37.89s of remaining time.
# 	0.8603	 = Validation roc_auc score
# 	5.0s	 = Training runtime
# 	0.19s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 32.59s of the 32.59s of remaining time.
# 	0.8666	 = Validation roc_auc score
# 	3.22s	 = Training runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetMXNet_BAG_L1 ... Training model for up to 29.14s of the 29.13s of remaining time.
# 	Ran out of time, stopping training early. (Stopping on epoch 16)
# 	Ran out of time, stopping training early. (Stopping on epoch 16)
# 	Ran out of time, stopping training early. (Stopping on epoch 17)
# 	Ran out of time, stopping training early. (Stopping on epoch 20)
# 	Ran out of time, stopping training early. (Stopping on epoch 23)
# 	0.7624	 = Validation roc_auc score
# 	26.87s	 = Training runtime
# 	1.09s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1.12s of the 1.12s of remaining time.
# 	Ran out of time, early stopping on iteration 1. Best iteration is:
# 	[1]	train_set's binary_logloss: 0.565968	valid_set's binary_logloss: 0.571936
# 	Time limit exceeded... Skipping LightGBMLarge_BAG_L1.
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 59.83s of the 0.75s of remaining time.
# 	0.9004	 = Validation roc_auc score
# 	1.86s	 = Training runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 61.16s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("agModels-predictClass_auc/")
#                       model  score_test  score_val  pred_time_test  \
# 0           CatBoost_BAG_L1    0.902783   0.887489        0.114899
# 1         LightGBMXT_BAG_L1    0.900161   0.881380        0.336767
# 2       WeightedEnsemble_L2    0.897607   0.900375        3.633572
# 3           LightGBM_BAG_L1    0.892347   0.866991        0.191905
# 4            XGBoost_BAG_L1    0.891681   0.866575        1.012777
# 5   RandomForestEntr_BAG_L1    0.888119   0.886301        0.243448
# 6   RandomForestGini_BAG_L1    0.886598   0.884698        0.228378
# 7     ExtraTreesGini_BAG_L1    0.881065   0.892927        0.234939
# 8     ExtraTreesEntr_BAG_L1    0.880851   0.893912        0.236822
# 9    NeuralNetFastAI_BAG_L1    0.880547   0.860274        2.460286
# 10    NeuralNetMXNet_BAG_L1    0.841838   0.762435       10.584518
# 11    KNeighborsDist_BAG_L1    0.525998   0.536956        0.112479
# 12    KNeighborsUnif_BAG_L1    0.514970   0.519604        0.110751
#
#     pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0        0.076702   8.371448                 0.114899                0.076702
# 1        0.163652   3.531663                 0.336767                0.163652
# 2        0.842155  20.818748                 0.006412                0.001966
# 3        0.261608   5.636509                 0.191905                0.261608
# 4        0.080954   3.224210                 1.012777                0.080954
# 5        0.136669   0.685285                 0.243448                0.136669
# 6        0.138456   0.786898                 0.228378                0.138456
# 7        0.135098   0.688073                 0.234939                0.135098
# 8        0.140500   0.681697                 0.236822                0.140500
# 9        0.187569   4.997181                 2.460286                0.187569
# 10       1.088244  26.872295                10.584518                1.088244
# 11       0.106394   0.002210                 0.112479                0.106394
# 12       0.108068   0.002828                 0.110751                0.108068
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0            8.371448            1       True          7
# 1            3.531663            1       True          3
# 2            1.863401            2       True         13
# 3            5.636509            1       True          4
# 4            3.224210            1       True         11
# 5            0.685285            1       True          6
# 6            0.786898            1       True          5
# 7            0.688073            1       True          8
# 8            0.681697            1       True          9
# 9            4.997181            1       True         10
# 10          26.872295            1       True         12
# 11           0.002210            1       True          2
# 12           0.002828            1       True          1
# <b>limit_output extension: Maximum message size of 10000 exceeded with 10883 characters</b>

# %% [markdown]
# # 回归

# %%
age_column = 'age'
print("Summary of age variable: \n", train_data[age_column].describe())
# Out:
# Summary of age variable:
#  count    500.00000
# mean      39.65200
# std       13.52393
# min       17.00000
# 25%       29.00000
# 50%       38.00000
# 75%       49.00000
# max       85.00000
# Name: age, dtype: float64

# %%
predictor_age = TabularPredictor(label=age_column, path="agModels-predictAge").fit(train_data, time_limit=60)
performance = predictor_age.evaluate(test_data)
# Out:
# Beginning AutoGluon training ... Time limit = 60s
# AutoGluon will save models to "agModels-predictAge/"
# AutoGluon Version:  0.2.0
# Train Data Rows:    500
# Train Data Columns: 14
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == int and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (85, 17, 39.652, 13.52393)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    214910.15 MB
# 	Train Data (Original)  Memory Usage: 0.32 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', [])    : 5 | ['fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']
# 		('object', []) : 9 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 9 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 		('int', [])      : 5 | ['fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']
# 	0.1s = Fit runtime
# 	14 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.03 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.11s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 400, Val Rows: 100
# Fitting model: KNeighborsUnif ... Training model for up to 59.89s of the 59.89s of remaining time.
# 	-15.6869	 = Validation root_mean_squared_error score
# 	0.0s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: KNeighborsDist ... Training model for up to 59.77s of the 59.77s of remaining time.
# 	-15.1801	 = Validation root_mean_squared_error score
# 	0.0s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMXT ... Training model for up to 59.66s of the 59.66s of remaining time.
# 	-11.8147	 = Validation root_mean_squared_error score
# 	0.82s	 = Training runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM ... Training model for up to 58.78s of the 58.78s of remaining time.
# 	-11.9295	 = Validation root_mean_squared_error score
# 	1.01s	 = Training runtime
# 	0.04s	 = Validation runtime
# Fitting model: RandomForestMSE ... Training model for up to 57.71s of the 57.71s of remaining time.
# 	-11.6028	 = Validation root_mean_squared_error score
# 	0.65s	 = Training runtime
# 	0.12s	 = Validation runtime
# Fitting model: CatBoost ... Training model for up to 56.91s of the 56.91s of remaining time.
# 	-11.7448	 = Validation root_mean_squared_error score
# 	0.97s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: ExtraTreesMSE ... Training model for up to 55.91s of the 55.91s of remaining time.
# 	-11.4808	 = Validation root_mean_squared_error score
# 	0.58s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetFastAI ... Training model for up to 55.2s of the 55.2s of remaining time.
# 	-39.0766	 = Validation root_mean_squared_error score
# 	1.13s	 = Training runtime
# 	0.04s	 = Validation runtime
# Fitting model: XGBoost ... Training model for up to 54.01s of the 54.01s of remaining time.
# 	-12.1743	 = Validation root_mean_squared_error score
# 	0.79s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetMXNet ... Training model for up to 53.15s of the 53.15s of remaining time.
# 	-13.5428	 = Validation root_mean_squared_error score
# 	8.19s	 = Training runtime
# 	0.21s	 = Validation runtime
# Fitting model: LightGBMLarge ... Training model for up to 44.75s of the 44.74s of remaining time.
# 	-12.1676	 = Validation root_mean_squared_error score
# 	2.3s	 = Training runtime
# 	0.04s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 59.89s of the 40.96s of remaining time.
# 	-11.3275	 = Validation root_mean_squared_error score
# 	0.68s	 = Training runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 19.76s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("agModels-predictAge/")
# Evaluation: root_mean_squared_error on test data: -10.504253448869648
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "root_mean_squared_error": -10.504253448869648,
#     "mean_squared_error": -110.33934051809648,
#     "mean_absolute_error": -8.278515720552914,
#     "r2": 0.4102148058842625,
#     "pearsonr": 0.6426462616649667,
#     "median_absolute_error": -6.980693817138672
# }

# %%
predictor_age.leaderboard(test_data, silent=True)
# Out:
#                   model  score_test  score_val  pred_time_test  pred_time_val  \
# 0   WeightedEnsemble_L2  -10.504253 -11.327516        2.812784       0.556022
# 1         ExtraTreesMSE  -10.691115 -11.480752        0.142555       0.114969
# 2       RandomForestMSE  -10.746518 -11.602848        0.136341       0.118001
# 3            LightGBMXT  -10.753344 -11.814712        0.112751       0.039148
# 4              CatBoost  -10.800412 -11.744795        0.063836       0.017125
# 5              LightGBM  -10.972156 -11.929546        0.103317       0.043093
# 6               XGBoost  -11.121008 -12.174270        0.129467       0.017468
# 7         LightGBMLarge  -11.598649 -12.167606        0.093236       0.035035
# 8        NeuralNetMXNet  -13.352706 -13.542799        2.116464       0.205460
# 9        KNeighborsUnif  -14.902058 -15.686937        0.110952       0.108677
# 10       KNeighborsDist  -15.771259 -15.180149        0.112333       0.108913
# 11      NeuralNetFastAI  -37.956546 -39.076578        0.472642       0.039099
#
#      fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0   13.684486                 0.008053                0.000758
# 1    0.575395                 0.142555                0.114969
# 2    0.653862                 0.136341                0.118001
# 3    0.815584                 0.112751                0.039148
# 4    0.974211                 0.063836                0.017125
# 5    1.013631                 0.103317                0.043093
# 6    0.787892                 0.129467                0.017468
# 7    2.295146                 0.093236                0.035035
# 8    8.186219                 2.116464                0.205460
# 9    0.003114                 0.110952                0.108677
# 10   0.002604                 0.112333                0.108913
# 11   1.128937                 0.472642                0.039099
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0            0.677693            2       True         12
# 1            0.575395            1       True          7
# 2            0.653862            1       True          5
# 3            0.815584            1       True          3
# 4            0.974211            1       True          6
# 5            1.013631            1       True          4
# 6            0.787892            1       True          9
# 7            2.295146            1       True         11
# 8            8.186219            1       True         10
# 9            0.003114            1       True          1
# 10           0.002604            1       True          2
# 11           1.128937            1       True          8
